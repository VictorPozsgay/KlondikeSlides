# %%
import os
import sys
from pathlib import Path
import pickle

# Insert path to the root of the package
path = Path(os.getcwd())
path_parent=str(path.parent.absolute())
path_module=path_parent+'/src/KlondikeSlides'
sys.path.insert(0, os.path.abspath(path_module))

from KlondikeSlides import format_all_raw_data

# %% [markdown]
# # Data formatting

# %%
path_data_raw = path_parent+'/data/raw'
path_data_processed = path_parent+'/data/processed'

path_wildfire_in  = path_data_raw+'/wildfire/klondikewildfire_polygondata.csv'
path_wildfire_out = path_data_processed+'/wildfire/wildfire.csv'
path_gst_logger_in  = path_data_raw+'/logger'
path_gst_logger_out = path_data_processed+'/logger'
path_forcing_ygs_sites_in  = path_data_raw+'/forcing/YGS_sites'
path_forcing_ygs_sites_out = path_data_processed+'/forcing/YGS_sites'
path_simulations_ygs_in  = path_data_raw+'/GEOtop_simulations/YGS_sites'
path_simulations_ygs_out = path_data_processed+'/GEOtop_simulations/YGS_sites'
path_paleo_Benthic_in  = path_data_raw+'/paleo_climate/LR04_stack.csv'
path_paleo_Benthic_out = path_data_processed+'/paleo_climate/Benthic.csv'
path_paleo_Greenland_in  = path_data_raw+'/paleo_climate/NGRIP_d18O.csv'
path_paleo_Greenland_out = path_data_processed+'/paleo_climate/Greenland.csv'
path_paleo_Yukon_in  = path_data_raw+'/paleo_climate/porter2019_yukon_temp.csv'
path_paleo_Yukon_out = path_data_processed+'/paleo_climate/Yukon.csv'

format_all_raw_data(path_wildfire_in, path_wildfire_out, path_gst_logger_in, path_gst_logger_out,
                    path_forcing_ygs_sites_in, path_forcing_ygs_sites_out,
                    path_simulations_ygs_in, path_simulations_ygs_out,
                    path_paleo_Benthic_in, path_paleo_Benthic_out,
                    path_paleo_Greenland_in, path_paleo_Greenland_out,
                    path_paleo_Yukon_in, path_paleo_Yukon_out)
