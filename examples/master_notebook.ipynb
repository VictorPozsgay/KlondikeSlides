# %%
import os
import sys
from pathlib import Path
import pickle

# Insert path to the root of the package
path = Path(os.getcwd())
path_parent=str(path.parent.absolute())
path_module=path_parent+'/src/KlondikeSlides'
sys.path.insert(0, os.path.abspath(path_module))

from KlondikeSlides import format_all_raw_data

# %% [markdown]
# # Data formatting

# %%
path_wildfire_in  = path_parent+'/data/raw/wildfire/klondikewildfire_polygondata.csv'
path_wildfire_out = path_parent+'/data/processed/wildfire/wildfire.csv'
path_gst_logger_in  = path_parent+'/data/raw/logger'
path_gst_logger_out = path_parent+'/data/processed/logger'
path_forcing_ygs_sites_in  = path_parent+'/data/raw/forcing/YGS_sites'
path_forcing_ygs_sites_out = path_parent+'/data/processed/forcing/YGS_sites'

format_all_raw_data(path_wildfire_in, path_wildfire_out, path_gst_logger_in, path_gst_logger_out, path_forcing_ygs_sites_in, path_forcing_ygs_sites_out)
